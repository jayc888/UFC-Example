# %% [markdown]
# # Explore here

# %%
# Your code here
import pandas as pd
df = pd.read_csv('UFC.csv')
df.head()
# Out:
#            event_id                              event_name        date  \
# 0  400c7b43c86d27d3  UFC Fight Night: Hill vs. Rountree Jr.  2025/06/21
# 1  400c7b43c86d27d3  UFC Fight Night: Hill vs. Rountree Jr.  2025/06/21
# 2  400c7b43c86d27d3  UFC Fight Night: Hill vs. Rountree Jr.  2025/06/21
# 3  400c7b43c86d27d3  UFC Fight Night: Hill vs. Rountree Jr.  2025/06/21
# 4  400c7b43c86d27d3  UFC Fight Night: Hill vs. Rountree Jr.  2025/06/21
#
#            location          fight_id           division  title_fight  \
# 0  Baku, Azerbaijan  36ec204f47e4d613       catch weight            0
# 1  Baku, Azerbaijan  a1afc16e21d1a807        lightweight            0
# 2  Baku, Azerbaijan  7513a00037094075        lightweight            0
# 3  Baku, Azerbaijan  e512b80bbaea36c2       welterweight            0
# 4  Baku, Azerbaijan  03bc32bdb5a33496  light heavyweight            0
#
#                  method  finish_round  match_time_sec  ...  b_splm b_str_acc  \
# ...

# %%
df.shape
# Out:
# (8250, 124)

# %%
pd.set_option('display.max_columns', 125)
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8250 entries, 0 to 8249
# Columns: 124 entries, event_id to winner_id
# dtypes: float64(87), int64(17), object(20)
# memory usage: 7.8+ MB
# None

# %%
print(df.sample(10))
# Out:
#               event_id                                 event_name        date  \
# 7603  baf942f4bcb09894  The Ultimate Fighter: The Comeback Finale  2006/11/11
# 397   079488710f012779   UFC Fight Night: Moicano vs. Saint Denis  2024/09/28
# 4295  5cde96e0a1a1fffe        UFC Fight Night: Bader vs. Nogueira  2016/11/19
# 5340  3bb030257966b022                UFC 178: Johnson vs Cariaso  2014/09/27
# 3237  e96d8538d3f9d0ed      UFC Fight Night: Lewis vs. Dos Santos  2019/03/09
# 5387  063649e21bc9d6d5    UFC Fight Night: Henderson vs Dos Anjos  2014/08/23
# 4722  380e8b023290d091                  UFC 195: Lawler vs Condit  2016/01/02
# 4430  a196332ee4aa8a82        UFC Fight Night: Lineker vs. Dodson  2016/10/01
# 543   9c5828c6fd9dc948           UFC Fight Night: Perez vs. Taira  2024/06/15
# 6361  b5ea750025697880               UFC on FX: Alves vs Kampmann  2012/03/02
#
#                                 location          fight_id           division  \
# ...

# %%
df['fight_id'].duplicated().sum()
# Out:
# np.int64(0)

# %%
print(df.isnull().head())
# Out:
#    event_id  event_name   date  location  fight_id  division  title_fight  \
# 0     False       False  False     False     False     False        False
# 1     False       False  False     False     False     False        False
# 2     False       False  False     False     False     False        False
# 3     False       False  False     False     False     False        False
# 4     False       False  False     False     False     False        False
#
#    method  finish_round  match_time_sec  total_rounds  referee  r_name   r_id  \
# 0   False         False           False         False    False   False  False
# 1   False         False           False         False    False   False  False
# 2   False         False           False         False    False   False  False
# 3   False         False           False         False    False   False  False
# 4   False         False           False         False    False   False  False
#
# ...

# %% [markdown]
# The following are the variables in the dataset and their meanings:
#
#   * `event_id`: Unique identifier for the event.
#   * `event_name`: Name of the UFC event.
#   * `date`: Date of the event.
#   * `location`: Location where the event took place.
#   * `fight_id`: Unique identifier for each fight.
#   * `division`: Weight division of the fight.
#   * `title_fight`: Indicates if it was a title fight (1 for Yes, 0 for No).
#   * `method`: Method by which the fight was won (e.g., KO, TKO, Decision, Submission).
#   * `finish_round`: The round in which the fight ended.
#   * `match_time_sec`: Time in seconds at which the fight ended in the given round.
#   * `total_rounds`: Total number of rounds in the fight.
#   * `referee`: Name of the referee for the fight.
#   * `r_name`: Red corner fighter's name.
#   * `r_id`: Red corner fighter's ID.
#   * `r_kd`: Knockdowns by the red corner fighter.
#   * `r_sig_str_landed`: Significant strikes landed by the red corner fighter.
#   * `r_sig_str_atmpted`: Significant strikes attempted by the red corner fighter.
#   * `r_sig_str_acc`: Significant strike accuracy for the red corner fighter (percentage).
#   * `r_total_str_landed`: Total strikes landed by the red corner fighter.
#   * `r_total_str_atmpted`: Total strikes attempted by the red corner fighter.
#   * `r_total_str_acc`: Total strike accuracy for the red corner fighter (percentage).
#   * `r_td_landed`: Takedowns landed by the red corner fighter.
#   * `r_td_atmpted`: Takedowns attempted by the red corner fighter.
#   * `r_td_acc`: Takedown accuracy for the red corner fighter (percentage).
#   * `r_sub_att`: Submission attempts by the red corner fighter.
#   * `r_ctrl`: Control time for the red corner fighter (in minutes:seconds format, needs conversion to seconds for numerical analysis).
#   * `r_head_landed`: Head strikes landed by the red corner fighter.
#   * `r_head_atmpted`: Head strikes attempted by the red corner fighter.
#   * `r_head_acc`: Head strike accuracy for the red corner fighter (percentage).
#   * `r_body_landed`: Body strikes landed by the red corner fighter.
#   * `r_body_atmpted`: Body strikes attempted by the red corner fighter.
#   * `r_body_acc`: Body strike accuracy for the red corner fighter (percentage).
#   * `r_leg_landed`: Leg strikes landed by the red corner fighter.
#   * `r_leg_atmpted`: Leg strikes attempted by the red corner fighter.
#   * `r_leg_acc`: Leg strike accuracy for the red corner fighter (percentage).
#   * `r_dist_landed`: Distance strikes landed by the red corner fighter.
#   * `r_dist_atmpted`: Distance strikes attempted by the red corner fighter.
#   * `r_dist_acc`: Distance strike accuracy for the red corner fighter (percentage).
#   * `r_clinch_landed`: Clinch strikes landed by the red corner fighter.
#   * `r_clinch_atmpted`: Clinch strikes attempted by the red corner fighter.
#   * `r_clinch_acc`: Clinch strike accuracy for the red corner fighter (percentage).
#   * `r_ground_landed`: Ground strikes landed by the red corner fighter.
#   * `r_ground_atmpted`: Ground strikes attempted by the red corner fighter.
#   * `r_ground_acc`: Ground strike accuracy for the red corner fighter (percentage).
#   * `r_landed_head_per`: Percentage of landed strikes that were head strikes for the red corner fighter.
#   * `r_landed_body_per`: Percentage of landed strikes that were body strikes for the red corner fighter.
#   * `r_landed_leg_per`: Percentage of landed strikes that were leg strikes for the red corner fighter.
#   * `r_landed_dist_per`: Percentage of landed strikes that were distance strikes for the red corner fighter.
#   * `r_landed_clinch_per`: Percentage of landed strikes that were clinch strikes for the red corner fighter.
#   * `r_landed_ground_per`: Percentage of landed strikes that were ground strikes for the red corner fighter.
#   * `r_nick_name`: Nickname of the red corner fighter.
#   * `r_wins`: Number of wins for the red corner fighter.
#   * `r_losses`: Number of losses for the red corner fighter.
#   * `r_draws`: Number of draws for the red corner fighter.
#   * `r_height`: Height of the red corner fighter (in cm).
#   * `r_weight`: Weight of the red corner fighter (in kg).
#   * `r_reach`: Reach of the red corner fighter (in cm).
#   * `r_stance`: Stance of the red corner fighter (e.g., Orthodox, Southpaw).
#   * `r_dob`: Date of birth of the red corner fighter.
#   * `r_splm`: Significant strikes landed per minute for the red corner fighter.
#   * `r_str_acc`: Significant strike accuracy for the red corner fighter.
#   * `r_sapm`: Significant strikes absorbed per minute for the red corner fighter.
#   * `r_str_def`: Significant strike defense for the red corner fighter.
#   * `r_td_avg`: Average takedowns landed per 15 minutes for the red corner fighter.
#   * `r_td_avg_acc`: Average takedown accuracy for the red corner fighter.
#   * `r_td_def`: Takedown defense for the red corner fighter.
#   * `r_sub_avg`: Average submission attempts per 15 minutes for the red corner fighter.
#   * `b_name`: Blue corner fighter's name.
#   * `b_id`: Blue corner fighter's ID.
#   * `b_kd`: Knockdowns by the blue corner fighter.
#   * `b_sig_str_landed`: Significant strikes landed by the blue corner fighter.
#   * `b_sig_str_atmpted`: Significant strikes attempted by the blue corner fighter.
#   * `b_sig_str_acc`: Significant strike accuracy for the blue corner fighter (percentage).
#   * `b_total_str_landed`: Total strikes landed by the blue corner fighter.
#   * `b_total_str_atmpted`: Total strikes attempted by the blue corner fighter.
#   * `b_total_str_acc`: Total strike accuracy for the blue corner fighter (percentage).
#   * `b_td_landed`: Takedowns landed by the blue corner fighter.
#   * `b_td_atmpted`: Takedowns attempted by the blue corner fighter.
#   * `b_td_acc`: Takedown accuracy for the blue corner fighter (percentage).
#   * `b_sub_att`: Submission attempts by the blue corner fighter.
#   * `b_ctrl`: Control time for the blue corner fighter (in minutes:seconds format, needs conversion to seconds for numerical analysis).
#   * `b_head_landed`: Head strikes landed by the blue corner fighter.
#   * `b_head_atmpted`: Head strikes attempted by the blue corner fighter.
#   * `b_head_acc`: Head strike accuracy for the blue corner fighter (percentage).
#   * `b_body_landed`: Body strikes landed by the blue corner fighter.
#   * `b_body_atmpted`: Body strikes attempted by the blue corner fighter.
#   * `b_body_acc`: Body strike accuracy for the blue corner fighter (percentage).
#   * `b_leg_landed`: Leg strikes landed by the blue corner fighter.
#   * `b_leg_atmpted`: Leg strikes attempted by the blue corner fighter.
#   * `b_leg_acc`: Leg strike accuracy for the blue corner fighter (percentage).
#   * `b_dist_landed`: Distance strikes landed by the blue corner fighter.
#   * `b_dist_atmpted`: Distance strikes attempted by the blue corner fighter.
#   * `b_dist_acc`: Distance strike accuracy for the blue corner fighter (percentage).
#   * `b_clinch_landed`: Clinch strikes landed by the blue corner fighter.
#   * `b_clinch_atmpted`: Clinch strikes attempted by the blue corner fighter.
#   * `b_clinch_acc`: Clinch strike accuracy for the blue corner fighter (percentage).
#   * `b_ground_landed`: Ground strikes landed by the blue corner fighter.
#   * `b_ground_atmpted`: Ground strikes attempted by the blue corner fighter.
#   * `b_ground_acc`: Ground strike accuracy for the blue corner fighter (percentage).
#   * `b_landed_head_per`: Percentage of landed strikes that were head strikes for the blue corner fighter.
#   * `b_landed_body_per`: Percentage of landed strikes that were body strikes for the blue corner fighter.
#   * `b_landed_leg_per`: Percentage of landed strikes that were leg strikes for the blue corner fighter.
#   * `b_landed_dist_per`: Percentage of landed strikes that were distance strikes for the blue corner fighter.
#   * `b_landed_clinch_per`: Percentage of landed strikes that were clinch strikes for the blue corner fighter.
#   * `b_landed_ground_per`: Percentage of landed strikes that were ground strikes for the blue corner fighter.
#   * `b_nick_name`: Nickname of the blue corner fighter.
#   * `b_wins`: Number of wins for the blue corner fighter.
#   * `b_losses`: Number of losses for the blue corner fighter.
#   * `b_draws`: Number of draws for the blue corner fighter.
#   * `b_height`: Height of the blue corner fighter (in cm).
#   * `b_weight`: Weight of the blue corner fighter (in kg).
#   * `b_reach`: Reach of the blue corner fighter (in cm).
#   * `b_stance`: Stance of the blue corner fighter (e.g., Orthodox, Southpaw).
#   * `b_dob`: Date of birth of the blue corner fighter.
#   * `b_splm`: Significant strikes landed per minute for the blue corner fighter.
#   * `b_str_acc`: Significant strike accuracy for the blue corner fighter.
#   * `b_sapm`: Significant strikes absorbed per minute for the blue corner fighter.
#   * `b_str_def`: Significant strike defense for the blue corner fighter.
#   * `b_td_avg`: Average takedowns landed per 15 minutes for the blue corner fighter.
#   * `b_td_avg_acc`: Average takedown accuracy for the blue corner fighter.
#   * `b_td_def`: Takedown defense for the blue corner fighter.
#   * `b_sub_avg`: Average submission attempts per 15 minutes for the blue corner fighter.
#   * `winner`: Name of the fight winner.
#   * `winner_id`: ID of the fight winner.
